# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from skimage.io import imread, imshow
from skimage.transform import resize # Using skimage instead of scipy.misc

from PIL import Image
import datetime
import os
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
# tf.set_random_seed(30)
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('datasets/Project_data/val.csv').readlines())
batch_size = 32 #experiment with the batch size

# %%
train_doc[0]
# Out:
# 'WIN_20180926_16_54_08_Pro_Right_Swipe_new;Right_Swipe_new;1\n'

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
import glob
img = imread(glob.glob(os.path.join("datasets/Project_data/train/", train_doc[263].split(';')[0], '*'))[15])
h = img.shape[0]
imshow(resize(img[75:-75, 50:-50, :], (100,100,3)))

# %%
import glob
img = imread(glob.glob(os.path.join("datasets/Project_data/train/", train_doc[173].split(';')[0], '*'))[15])
h = img.shape[0]
imshow(resize(img[75:-75, 50:-50, :], (100,100,3)))

# %%
x = 20 # Number of images per video
y = 80 # Height of the image
z = 80 # width of the image

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = list(range(6, 24)) #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(t)/batch_size) # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size, x, y, z ,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if image.shape[0]>120:
                        img_crop = image[75:-75, 50:-50, :] # Cropping for 360X360
                    else:
                        img_crop = image[25:-25, 30:-30, :] # Cropping for 120X160
                    
                    final_image = resize(img_crop, (y, z, 3))
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    batch_data[folder, idx, :,:,:] = final_image
                    batch_data[folder,idx,:,:,0] = batch_data[folder,idx,:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = batch_data[folder,idx,:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = batch_data[folder,idx,:,:,2]/255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if(len(t)%batch_size) != 0:
            batch_data = np.zeros((len(t)%batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB x,y,z = 18,84,84
            batch_labels = np.zeros((len(t)%batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(len(t)%batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    if image.shape[0]>120:
                        img_crop = image[75:-75, 50:-50, :]
                    else:
                        img_crop = image[25:-25, 30:-30, :]
                    
                    final_image = resize(img_crop, (y, z, 3))
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    batch_data[folder, idx, :,:,:] = final_image
                    
                    batch_data[folder,idx,:,:,0] = batch_data[folder,idx,:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = batch_data[folder,idx,:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = batch_data[folder,idx,:,:,2]/255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1 # OHE
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'datasets/Project_data/train/'
val_path = 'datasets/Project_data/val/'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 30 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.regularizers import l2

#write your model here
model = Sequential()
model.add(Conv3D(32, (3,3,3), padding="same", input_shape=(x,y,z,3)))
model.add(BatchNormalization())
model.add(Activation("elu"))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(64, (3,3,3), padding="same"))
model.add(BatchNormalization())
model.add(Activation("elu"))
model.add(MaxPooling3D(pool_size=(3,4,4)))

model.add(Flatten())
model.add(Dense(192, activation="elu"))
model.add(Dropout(0.35))
model.add(Dense(5, activation="softmax"))
# Out:
# 2023-09-02 04:55:58.788692: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-09-02 04:55:58.788750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22851 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:1e:00.0, compute capability: 7.5

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 80, 80, 32)    2624
#
#  batch_normalization (BatchN  (None, 20, 80, 80, 32)   128
#  ormalization)
#
#  activation (Activation)     (None, 20, 80, 80, 32)    0
#
#  max_pooling3d (MaxPooling3D  (None, 10, 40, 40, 32)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 10, 40, 40, 64)    55360
#
#  batch_normalization_1 (Batc  (None, 10, 40, 40, 64)   256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 10, 40, 40, 64)    0
#
#  max_pooling3d_1 (MaxPooling  (None, 3, 10, 10, 64)    0
#  3D)
#
#  flatten (Flatten)           (None, 19200)             0
#
#  dense (Dense)               (None, 192)               3686592
#
#  dropout (Dropout)           (None, 192)               0
#
#  dense_1 (Dense)             (None, 5)                 965
#
# =================================================================
# Total params: 3,745,925
# Trainable params: 3,745,733
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, 
                             save_weights_only=False, mode='auto', save_freq='epoch')
# write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1,
                      mode="min", cooldown=0, min_lr=0.00001) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  datasets/Project_data/train/ ; batch size = 32
# Epoch 1/30
# 2023-09-02 04:56:02.894828: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 21/21 [==============================] - ETA: 0s - loss: 3.6171 - categorical_accuracy: 0.2866Source path =  datasets/Project_data/val/ ; batch size = 32
#
# Epoch 00001: saving model to model_init_2023-09-0204_55_58.136552/model-00001-3.61713-0.28658-1.75990-0.26000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 3.6171 - categorical_accuracy: 0.2866 - val_loss: 1.7599 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/30
# 21/21 [==============================] - ETA: 0s - loss: 1.5629 - categorical_accuracy: 0.3620
# Epoch 00002: saving model to model_init_2023-09-0204_55_58.136552/model-00002-1.56287-0.36199-1.71388-0.25000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 1.5629 - categorical_accuracy: 0.3620 - val_loss: 1.7139 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/30
# 21/21 [==============================] - ETA: 0s - loss: 1.3942 - categorical_accuracy: 0.4465
# Epoch 00003: saving model to model_init_2023-09-0204_55_58.136552/model-00003-1.39416-0.44646-1.71811-0.16000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.3942 - categorical_accuracy: 0.4465 - val_loss: 1.7181 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 4/30
# 21/21 [==============================] - ETA: 0s - loss: 1.2293 - categorical_accuracy: 0.5143
# Epoch 00004: saving model to model_init_2023-09-0204_55_58.136552/model-00004-1.22934-0.51433-1.24267-0.49000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 1.2293 - categorical_accuracy: 0.5143 - val_loss: 1.2427 - val_categorical_accuracy: 0.4900 - lr: 0.0010
# Epoch 5/30
# 21/21 [==============================] - ETA: 0s - loss: 1.0742 - categorical_accuracy: 0.5777
# Epoch 00005: saving model to model_init_2023-09-0204_55_58.136552/model-00005-1.07425-0.57768-1.38720-0.45000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 1.0742 - categorical_accuracy: 0.5777 - val_loss: 1.3872 - val_categorical_accuracy: 0.4500 - lr: 0.0010
# Epoch 6/30
# 21/21 [==============================] - ETA: 0s - loss: 0.9025 - categorical_accuracy: 0.6440
# Epoch 00006: saving model to model_init_2023-09-0204_55_58.136552/model-00006-0.90250-0.64404-1.65270-0.43000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 [==============================] - 68s 3s/step - loss: 0.9025 - categorical_accuracy: 0.6440 - val_loss: 1.6527 - val_categorical_accuracy: 0.4300 - lr: 0.0010
# Epoch 7/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7292 - categorical_accuracy: 0.7119
# Epoch 00007: saving model to model_init_2023-09-0204_55_58.136552/model-00007-0.72923-0.71192-1.76870-0.39000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.7292 - categorical_accuracy: 0.7119 - val_loss: 1.7687 - val_categorical_accuracy: 0.3900 - lr: 5.0000e-04
# Epoch 8/30
# 21/21 [==============================] - ETA: 0s - loss: 0.6552 - categorical_accuracy: 0.7360
# Epoch 00008: saving model to model_init_2023-09-0204_55_58.136552/model-00008-0.65517-0.73605-1.95900-0.35000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 [==============================] - 65s 3s/step - loss: 0.6552 - categorical_accuracy: 0.7360 - val_loss: 1.9590 - val_categorical_accuracy: 0.3500 - lr: 5.0000e-04
# Epoch 9/30
# 21/21 [==============================] - ETA: 0s - loss: 0.5498 - categorical_accuracy: 0.7919
# Epoch 00009: saving model to model_init_2023-09-0204_55_58.136552/model-00009-0.54975-0.79186-2.41597-0.36000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.5498 - categorical_accuracy: 0.7919 - val_loss: 2.4160 - val_categorical_accuracy: 0.3600 - lr: 2.5000e-04
# Epoch 10/30
# 21/21 [==============================] - ETA: 0s - loss: 0.5445 - categorical_accuracy: 0.7919
# Epoch 00010: saving model to model_init_2023-09-0204_55_58.136552/model-00010-0.54447-0.79186-2.33366-0.34000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 21/21 [==============================] - 68s 3s/step - loss: 0.5445 - categorical_accuracy: 0.7919 - val_loss: 2.3337 - val_categorical_accuracy: 0.3400 - lr: 2.5000e-04
# Epoch 11/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4839 - categorical_accuracy: 0.8341
# Epoch 00011: saving model to model_init_2023-09-0204_55_58.136552/model-00011-0.48393-0.83409-2.32174-0.39000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4839 - categorical_accuracy: 0.8341 - val_loss: 2.3217 - val_categorical_accuracy: 0.3900 - lr: 1.2500e-04
# Epoch 12/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4911 - categorical_accuracy: 0.8296
# Epoch 00012: saving model to model_init_2023-09-0204_55_58.136552/model-00012-0.49113-0.82956-2.29805-0.38000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 21/21 [==============================] - 66s 3s/step - loss: 0.4911 - categorical_accuracy: 0.8296 - val_loss: 2.2980 - val_categorical_accuracy: 0.3800 - lr: 1.2500e-04
# Epoch 13/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4507 - categorical_accuracy: 0.8311
# Epoch 00013: saving model to model_init_2023-09-0204_55_58.136552/model-00013-0.45071-0.83107-2.27094-0.34000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 0.4507 - categorical_accuracy: 0.8311 - val_loss: 2.2709 - val_categorical_accuracy: 0.3400 - lr: 6.2500e-05
# Epoch 14/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4449 - categorical_accuracy: 0.8416
# Epoch 00014: saving model to model_init_2023-09-0204_55_58.136552/model-00014-0.44495-0.84163-2.19905-0.39000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 21/21 [==============================] - 69s 3s/step - loss: 0.4449 - categorical_accuracy: 0.8416 - val_loss: 2.1990 - val_categorical_accuracy: 0.3900 - lr: 6.2500e-05
# Epoch 15/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4471 - categorical_accuracy: 0.8416
# Epoch 00015: saving model to model_init_2023-09-0204_55_58.136552/model-00015-0.44715-0.84163-2.10898-0.39000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.4471 - categorical_accuracy: 0.8416 - val_loss: 2.1090 - val_categorical_accuracy: 0.3900 - lr: 3.1250e-05
# Epoch 16/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4440 - categorical_accuracy: 0.8220
# Epoch 00016: saving model to model_init_2023-09-0204_55_58.136552/model-00016-0.44398-0.82202-1.98267-0.44000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 21/21 [==============================] - 65s 3s/step - loss: 0.4440 - categorical_accuracy: 0.8220 - val_loss: 1.9827 - val_categorical_accuracy: 0.4400 - lr: 3.1250e-05
# Epoch 17/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4814 - categorical_accuracy: 0.8009
# Epoch 00017: saving model to model_init_2023-09-0204_55_58.136552/model-00017-0.48145-0.80090-1.72866-0.49000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4814 - categorical_accuracy: 0.8009 - val_loss: 1.7287 - val_categorical_accuracy: 0.4900 - lr: 1.5625e-05
# Epoch 18/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4613 - categorical_accuracy: 0.8296
# Epoch 00018: saving model to model_init_2023-09-0204_55_58.136552/model-00018-0.46129-0.82956-1.73979-0.52000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1e-05.
# 21/21 [==============================] - 68s 3s/step - loss: 0.4613 - categorical_accuracy: 0.8296 - val_loss: 1.7398 - val_categorical_accuracy: 0.5200 - lr: 1.5625e-05
# Epoch 19/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4488 - categorical_accuracy: 0.8326
# Epoch 00019: saving model to model_init_2023-09-0204_55_58.136552/model-00019-0.44881-0.83258-1.45436-0.54000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.4488 - categorical_accuracy: 0.8326 - val_loss: 1.4544 - val_categorical_accuracy: 0.5400 - lr: 1.0000e-05
# Epoch 20/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4747 - categorical_accuracy: 0.8296
# Epoch 00020: saving model to model_init_2023-09-0204_55_58.136552/model-00020-0.47465-0.82956-1.35231-0.55000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 0.4747 - categorical_accuracy: 0.8296 - val_loss: 1.3523 - val_categorical_accuracy: 0.5500 - lr: 1.0000e-05
# Epoch 21/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4557 - categorical_accuracy: 0.8296
# Epoch 00021: saving model to model_init_2023-09-0204_55_58.136552/model-00021-0.45570-0.82956-1.26642-0.56000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4557 - categorical_accuracy: 0.8296 - val_loss: 1.2664 - val_categorical_accuracy: 0.5600 - lr: 1.0000e-05
# Epoch 22/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4492 - categorical_accuracy: 0.8205
# Epoch 00022: saving model to model_init_2023-09-0204_55_58.136552/model-00022-0.44919-0.82051-1.15260-0.60000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4492 - categorical_accuracy: 0.8205 - val_loss: 1.1526 - val_categorical_accuracy: 0.6000 - lr: 1.0000e-05
# Epoch 23/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4518 - categorical_accuracy: 0.8326
# Epoch 00023: saving model to model_init_2023-09-0204_55_58.136552/model-00023-0.45184-0.83258-1.06947-0.65000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4518 - categorical_accuracy: 0.8326 - val_loss: 1.0695 - val_categorical_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 24/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4863 - categorical_accuracy: 0.8039
# Epoch 00024: saving model to model_init_2023-09-0204_55_58.136552/model-00024-0.48625-0.80392-1.10008-0.68000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 0.4863 - categorical_accuracy: 0.8039 - val_loss: 1.1001 - val_categorical_accuracy: 0.6800 - lr: 1.0000e-05
# Epoch 25/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4471 - categorical_accuracy: 0.8281
# Epoch 00025: saving model to model_init_2023-09-0204_55_58.136552/model-00025-0.44708-0.82805-0.99538-0.68000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4471 - categorical_accuracy: 0.8281 - val_loss: 0.9954 - val_categorical_accuracy: 0.6800 - lr: 1.0000e-05
# Epoch 26/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4076 - categorical_accuracy: 0.8477
# Epoch 00026: saving model to model_init_2023-09-0204_55_58.136552/model-00026-0.40762-0.84766-1.05663-0.66000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4076 - categorical_accuracy: 0.8477 - val_loss: 1.0566 - val_categorical_accuracy: 0.6600 - lr: 1.0000e-05
# Epoch 27/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4265 - categorical_accuracy: 0.8552
# Epoch 00027: saving model to model_init_2023-09-0204_55_58.136552/model-00027-0.42655-0.85520-0.79193-0.74000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4265 - categorical_accuracy: 0.8552 - val_loss: 0.7919 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-05
# Epoch 28/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4204 - categorical_accuracy: 0.8401
# Epoch 00028: saving model to model_init_2023-09-0204_55_58.136552/model-00028-0.42044-0.84012-0.89215-0.74000.h5
# 21/21 [==============================] - 64s 3s/step - loss: 0.4204 - categorical_accuracy: 0.8401 - val_loss: 0.8921 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-05
# Epoch 29/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4418 - categorical_accuracy: 0.8311
# Epoch 00029: saving model to model_init_2023-09-0204_55_58.136552/model-00029-0.44183-0.83107-0.87875-0.73000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4418 - categorical_accuracy: 0.8311 - val_loss: 0.8788 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-05
# Epoch 30/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4248 - categorical_accuracy: 0.8371
# Epoch 00030: saving model to model_init_2023-09-0204_55_58.136552/model-00030-0.42480-0.83710-0.76771-0.81000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4248 - categorical_accuracy: 0.8371 - val_loss: 0.7677 - val_categorical_accuracy: 0.8100 - lr: 1.0000e-05

# %% [markdown]
# ## So the Conv3D Model with 30 epochs gave us train and validation accuracy of 83% and 81% respectively
# ## Now we'll try with another model
# ## Tranfer Learning (VGG16) + RNN (GRU)

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Dense, Input, TimeDistributed, GlobalAveragePooling2D, GRU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

video = Input(shape=(x, y, z, 3))
cnn_base = VGG16(input_shape=(y, z, 3), weights="imagenet", include_top=False)
cnn_out = GlobalAveragePooling2D()(cnn_base.output)
cnn = Model(inputs=cnn_base.input, outputs=cnn_out)
for i in range(17):
    cnn.layers[i].trainable = False

encoded_frames = TimeDistributed(cnn)(video)
encoded_sequence = GRU(256)(encoded_frames)
hidden_layer = Dense(215, activation="relu")(encoded_sequence)
outputs = Dense(5, activation="softmax")(hidden_layer)
model = Model([video], outputs)

# %% [markdown]
# Now that you have written the model, the next step is to compile the model. When you print the summary of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 20, 80, 80, 3)]   0
#
#  time_distributed_4 (TimeDis  (None, 20, 512)          14714688
#  tributed)
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dense_13 (Dense)            (None, 215)               55255
#
#  dense_14 (Dense)            (None, 5)                 1080
#
# =================================================================
# Total params: 15,362,383
# Trainable params: 3,007,503
# Non-trainable params: 12,354,880
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the train_generator and the val_generator which will be used in .fit_generator.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, 
                             save_weights_only=False, mode='auto', save_freq='epoch')
# write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1,
                      mode="min", cooldown=0, min_lr=0.00001) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 21/21 [==============================] - ETA: 0s - loss: 1.6155 - categorical_accuracy: 0.2293Source path =  datasets/Project_data/val/ ; batch size = 32
#
# Epoch 00001: saving model to model_init_2023-09-0205_44_57.428028/model-00001-1.61550-0.22926-1.60803-0.20000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 1.6155 - categorical_accuracy: 0.2293 - val_loss: 1.6080 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/30
# 21/21 [==============================] - ETA: 0s - loss: 1.5740 - categorical_accuracy: 0.3288
# Epoch 00002: saving model to model_init_2023-09-0205_44_57.428028/model-00002-1.57395-0.32881-1.56950-0.24000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 1.5740 - categorical_accuracy: 0.3288 - val_loss: 1.5695 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 3/30
# 21/21 [==============================] - ETA: 0s - loss: 1.5473 - categorical_accuracy: 0.3288
# Epoch 00003: saving model to model_init_2023-09-0205_44_57.428028/model-00003-1.54730-0.32881-1.55026-0.31000.h5
# 21/21 [==============================] - 71s 4s/step - loss: 1.5473 - categorical_accuracy: 0.3288 - val_loss: 1.5503 - val_categorical_accuracy: 0.3100 - lr: 0.0010
# Epoch 4/30
# 21/21 [==============================] - ETA: 0s - loss: 1.5135 - categorical_accuracy: 0.4163
# Epoch 00004: saving model to model_init_2023-09-0205_44_57.428028/model-00004-1.51345-0.41629-1.50625-0.47000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 1.5135 - categorical_accuracy: 0.4163 - val_loss: 1.5062 - val_categorical_accuracy: 0.4700 - lr: 0.0010
# Epoch 5/30
# 21/21 [==============================] - ETA: 0s - loss: 1.4564 - categorical_accuracy: 0.4887
# Epoch 00005: saving model to model_init_2023-09-0205_44_57.428028/model-00005-1.45645-0.48869-1.46706-0.40000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.4564 - categorical_accuracy: 0.4887 - val_loss: 1.4671 - val_categorical_accuracy: 0.4000 - lr: 0.0010
# Epoch 6/30
# 21/21 [==============================] - ETA: 0s - loss: 1.3991 - categorical_accuracy: 0.5626
# Epoch 00006: saving model to model_init_2023-09-0205_44_57.428028/model-00006-1.39906-0.56259-1.40173-0.52000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.3991 - categorical_accuracy: 0.5626 - val_loss: 1.4017 - val_categorical_accuracy: 0.5200 - lr: 0.0010
# Epoch 7/30
# 21/21 [==============================] - ETA: 0s - loss: 1.3230 - categorical_accuracy: 0.6033
# Epoch 00007: saving model to model_init_2023-09-0205_44_57.428028/model-00007-1.32302-0.60332-1.35597-0.53000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.3230 - categorical_accuracy: 0.6033 - val_loss: 1.3560 - val_categorical_accuracy: 0.5300 - lr: 0.0010
# Epoch 8/30
# 21/21 [==============================] - ETA: 0s - loss: 1.2380 - categorical_accuracy: 0.6184
# Epoch 00008: saving model to model_init_2023-09-0205_44_57.428028/model-00008-1.23797-0.61840-1.23920-0.63000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 1.2380 - categorical_accuracy: 0.6184 - val_loss: 1.2392 - val_categorical_accuracy: 0.6300 - lr: 0.0010
# Epoch 9/30
# 21/21 [==============================] - ETA: 0s - loss: 1.1384 - categorical_accuracy: 0.6637
# Epoch 00009: saving model to model_init_2023-09-0205_44_57.428028/model-00009-1.13840-0.66365-1.14533-0.65000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.1384 - categorical_accuracy: 0.6637 - val_loss: 1.1453 - val_categorical_accuracy: 0.6500 - lr: 0.0010
# Epoch 10/30
# 21/21 [==============================] - ETA: 0s - loss: 1.0524 - categorical_accuracy: 0.6516
# Epoch 00010: saving model to model_init_2023-09-0205_44_57.428028/model-00010-1.05238-0.65158-1.00171-0.58000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 1.0524 - categorical_accuracy: 0.6516 - val_loss: 1.0017 - val_categorical_accuracy: 0.5800 - lr: 0.0010
# Epoch 11/30
# 21/21 [==============================] - ETA: 0s - loss: 0.9744 - categorical_accuracy: 0.6848
# Epoch 00011: saving model to model_init_2023-09-0205_44_57.428028/model-00011-0.97445-0.68477-0.95270-0.62000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.9744 - categorical_accuracy: 0.6848 - val_loss: 0.9527 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 12/30
# 21/21 [==============================] - ETA: 0s - loss: 0.8704 - categorical_accuracy: 0.6923
# Epoch 00012: saving model to model_init_2023-09-0205_44_57.428028/model-00012-0.87038-0.69231-0.92388-0.62000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 0.8704 - categorical_accuracy: 0.6923 - val_loss: 0.9239 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 13/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7868 - categorical_accuracy: 0.7421
# Epoch 00013: saving model to model_init_2023-09-0205_44_57.428028/model-00013-0.78680-0.74208-0.89859-0.66000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 0.7868 - categorical_accuracy: 0.7421 - val_loss: 0.8986 - val_categorical_accuracy: 0.6600 - lr: 0.0010
# Epoch 14/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7488 - categorical_accuracy: 0.7300
# Epoch 00014: saving model to model_init_2023-09-0205_44_57.428028/model-00014-0.74885-0.73002-0.79964-0.60000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.7488 - categorical_accuracy: 0.7300 - val_loss: 0.7996 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 15/30
# 21/21 [==============================] - ETA: 0s - loss: 0.6646 - categorical_accuracy: 0.7707
# Epoch 00015: saving model to model_init_2023-09-0205_44_57.428028/model-00015-0.66465-0.77074-0.77916-0.69000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.6646 - categorical_accuracy: 0.7707 - val_loss: 0.7792 - val_categorical_accuracy: 0.6900 - lr: 0.0010
# Epoch 16/30
# 21/21 [==============================] - ETA: 0s - loss: 0.5988 - categorical_accuracy: 0.8100
# Epoch 00016: saving model to model_init_2023-09-0205_44_57.428028/model-00016-0.59879-0.80995-0.80659-0.67000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 0.5988 - categorical_accuracy: 0.8100 - val_loss: 0.8066 - val_categorical_accuracy: 0.6700 - lr: 0.0010
# Epoch 17/30
# 21/21 [==============================] - ETA: 0s - loss: 0.5850 - categorical_accuracy: 0.7903
# Epoch 00017: saving model to model_init_2023-09-0205_44_57.428028/model-00017-0.58499-0.79035-0.72113-0.70000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.5850 - categorical_accuracy: 0.7903 - val_loss: 0.7211 - val_categorical_accuracy: 0.7000 - lr: 0.0010
# Epoch 18/30
# 21/21 [==============================] - ETA: 0s - loss: 0.5154 - categorical_accuracy: 0.8220
# Epoch 00018: saving model to model_init_2023-09-0205_44_57.428028/model-00018-0.51539-0.82202-0.69687-0.71000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.5154 - categorical_accuracy: 0.8220 - val_loss: 0.6969 - val_categorical_accuracy: 0.7100 - lr: 0.0010
# Epoch 19/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4781 - categorical_accuracy: 0.8296
# Epoch 00019: saving model to model_init_2023-09-0205_44_57.428028/model-00019-0.47813-0.82956-0.65524-0.74000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.4781 - categorical_accuracy: 0.8296 - val_loss: 0.6552 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 20/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4455 - categorical_accuracy: 0.8477
# Epoch 00020: saving model to model_init_2023-09-0205_44_57.428028/model-00020-0.44547-0.84766-0.71456-0.67000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 0.4455 - categorical_accuracy: 0.8477 - val_loss: 0.7146 - val_categorical_accuracy: 0.6700 - lr: 0.0010
# Epoch 21/30
# 21/21 [==============================] - ETA: 0s - loss: 0.4353 - categorical_accuracy: 0.8431
# Epoch 00021: saving model to model_init_2023-09-0205_44_57.428028/model-00021-0.43527-0.84314-0.66871-0.73000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 [==============================] - 68s 3s/step - loss: 0.4353 - categorical_accuracy: 0.8431 - val_loss: 0.6687 - val_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 22/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3858 - categorical_accuracy: 0.8748
# Epoch 00022: saving model to model_init_2023-09-0205_44_57.428028/model-00022-0.38580-0.87481-0.60808-0.72000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.3858 - categorical_accuracy: 0.8748 - val_loss: 0.6081 - val_categorical_accuracy: 0.7200 - lr: 5.0000e-04
# Epoch 23/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3611 - categorical_accuracy: 0.8899
# Epoch 00023: saving model to model_init_2023-09-0205_44_57.428028/model-00023-0.36106-0.88989-0.62292-0.73000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.3611 - categorical_accuracy: 0.8899 - val_loss: 0.6229 - val_categorical_accuracy: 0.7300 - lr: 5.0000e-04
# Epoch 24/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3545 - categorical_accuracy: 0.8793
# Epoch 00024: saving model to model_init_2023-09-0205_44_57.428028/model-00024-0.35454-0.87934-0.64460-0.73000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 [==============================] - 64s 3s/step - loss: 0.3545 - categorical_accuracy: 0.8793 - val_loss: 0.6446 - val_categorical_accuracy: 0.7300 - lr: 5.0000e-04
# Epoch 25/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3330 - categorical_accuracy: 0.9035
# Epoch 00025: saving model to model_init_2023-09-0205_44_57.428028/model-00025-0.33300-0.90347-0.62434-0.73000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.3330 - categorical_accuracy: 0.9035 - val_loss: 0.6243 - val_categorical_accuracy: 0.7300 - lr: 2.5000e-04
# Epoch 26/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3225 - categorical_accuracy: 0.8884
# Epoch 00026: saving model to model_init_2023-09-0205_44_57.428028/model-00026-0.32245-0.88839-0.61779-0.76000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 21/21 [==============================] - 67s 3s/step - loss: 0.3225 - categorical_accuracy: 0.8884 - val_loss: 0.6178 - val_categorical_accuracy: 0.7600 - lr: 2.5000e-04
# Epoch 27/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3130 - categorical_accuracy: 0.9065
# Epoch 00027: saving model to model_init_2023-09-0205_44_57.428028/model-00027-0.31296-0.90649-0.59428-0.73000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.3130 - categorical_accuracy: 0.9065 - val_loss: 0.5943 - val_categorical_accuracy: 0.7300 - lr: 1.2500e-04
# Epoch 28/30
# 21/21 [==============================] - ETA: 0s - loss: 0.3138 - categorical_accuracy: 0.9110
# Epoch 00028: saving model to model_init_2023-09-0205_44_57.428028/model-00028-0.31384-0.91101-0.61247-0.73000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 0.3138 - categorical_accuracy: 0.9110 - val_loss: 0.6125 - val_categorical_accuracy: 0.7300 - lr: 1.2500e-04
# Epoch 29/30
# 21/21 [==============================] - ETA: 0s - loss: 0.2950 - categorical_accuracy: 0.9080
# Epoch 00029: saving model to model_init_2023-09-0205_44_57.428028/model-00029-0.29503-0.90799-0.61452-0.70000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 21/21 [==============================] - 67s 3s/step - loss: 0.2950 - categorical_accuracy: 0.9080 - val_loss: 0.6145 - val_categorical_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 30/30
# 21/21 [==============================] - ETA: 0s - loss: 0.2937 - categorical_accuracy: 0.9201
# Epoch 00030: saving model to model_init_2023-09-0205_44_57.428028/model-00030-0.29375-0.92006-0.58920-0.73000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 0.2937 - categorical_accuracy: 0.9201 - val_loss: 0.5892 - val_categorical_accuracy: 0.7300 - lr: 6.2500e-05

# %% [markdown]
# ## So the Tranfer Learning (VGG16) + RNN (GRU) with 30 epochs gave us train and validation accuracy of 92% and 73% respectively
# ## Now we'll try with another model
# ## CNN + RNN (GRU)

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, Input, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.regularizers import l2

#write your model here
video = Input(shape=(x,y,z,3))
cnn_base = Sequential()

cnn_base.add(Conv2D(32, (3,3), activation='elu', padding='same'))
cnn_base.add(BatchNormalization())
cnn_base.add(MaxPooling2D((2,2)))

cnn_base.add(Conv2D(64, (3,3), activation='elu', padding='same'))
cnn_base.add(BatchNormalization())
cnn_base.add(MaxPooling2D((4,4)))

cnn_base.add(Flatten())
cnn_base.add(Dense(128, activation='relu'))
cnn_base.add(Dropout(0.5))

encoded_frames = TimeDistributed(cnn_base)(video)
gru1 = LSTM(256)(encoded_frames)
dropout1 = Dropout(0.5)(gru1)
hidden_layer = Dense(256, activation="relu")(dropout1)
dropout2 = Dropout(0.5)(hidden_layer)
outputs = Dense(5, activation="softmax")(dropout2)
model = Model([video], outputs)

# %% [markdown]
# Now that you have written the model, the next step is to compile the model. When you print the summary of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 20, 80, 80, 3)]   0
#
#  time_distributed_5 (TimeDis  (None, 20, 128)          839104
#  tributed)
#
#  lstm_3 (LSTM)               (None, 256)               394240
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1,300,421
# Trainable params: 1,300,229
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the train_generator and the val_generator which will be used in .fit_generator.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()

model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False,
                             save_weights_only=False, mode='auto', save_freq='epoch')

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1,
                      mode="min", cooldown=0, min_lr=0.00001) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  datasets/Project_data/train/ ; batch size = 32
# Epoch 1/30
# 21/21 [==============================] - ETA: 0s - loss: 1.7131 - categorical_accuracy: 0.1946Source path =  datasets/Project_data/val/ ; batch size = 32
#
# Epoch 00001: saving model to model_init_2023-09-0206_29_59.011351/model-00001-1.71309-0.19457-1.61061-0.18000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 1.7131 - categorical_accuracy: 0.1946 - val_loss: 1.6106 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 2/30
# 21/21 [==============================] - ETA: 0s - loss: 1.6379 - categorical_accuracy: 0.2247
# Epoch 00002: saving model to model_init_2023-09-0206_29_59.011351/model-00002-1.63789-0.22474-1.59803-0.26000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.6379 - categorical_accuracy: 0.2247 - val_loss: 1.5980 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 3/30
# 21/21 [==============================] - ETA: 0s - loss: 1.6157 - categorical_accuracy: 0.2459
# Epoch 00003: saving model to model_init_2023-09-0206_29_59.011351/model-00003-1.61572-0.24585-1.58543-0.32000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 1.6157 - categorical_accuracy: 0.2459 - val_loss: 1.5854 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 4/30
# 21/21 [==============================] - ETA: 0s - loss: 1.5637 - categorical_accuracy: 0.3017
# Epoch 00004: saving model to model_init_2023-09-0206_29_59.011351/model-00004-1.56372-0.30166-1.56618-0.35000.h5
# 21/21 [==============================] - 64s 3s/step - loss: 1.5637 - categorical_accuracy: 0.3017 - val_loss: 1.5662 - val_categorical_accuracy: 0.3500 - lr: 0.0010
# Epoch 5/30
# 21/21 [==============================] - ETA: 0s - loss: 1.5162 - categorical_accuracy: 0.3077
# Epoch 00005: saving model to model_init_2023-09-0206_29_59.011351/model-00005-1.51616-0.30769-1.54028-0.29000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 1.5162 - categorical_accuracy: 0.3077 - val_loss: 1.5403 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 6/30
# 21/21 [==============================] - ETA: 0s - loss: 1.4665 - categorical_accuracy: 0.3695
# Epoch 00006: saving model to model_init_2023-09-0206_29_59.011351/model-00006-1.46649-0.36953-1.52081-0.35000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.4665 - categorical_accuracy: 0.3695 - val_loss: 1.5208 - val_categorical_accuracy: 0.3500 - lr: 0.0010
# Epoch 7/30
# 21/21 [==============================] - ETA: 0s - loss: 1.4169 - categorical_accuracy: 0.3635
# Epoch 00007: saving model to model_init_2023-09-0206_29_59.011351/model-00007-1.41693-0.36350-1.43072-0.39000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.4169 - categorical_accuracy: 0.3635 - val_loss: 1.4307 - val_categorical_accuracy: 0.3900 - lr: 0.0010
# Epoch 8/30
# 21/21 [==============================] - ETA: 0s - loss: 1.3623 - categorical_accuracy: 0.4193
# Epoch 00008: saving model to model_init_2023-09-0206_29_59.011351/model-00008-1.36229-0.41931-1.38354-0.48000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 1.3623 - categorical_accuracy: 0.4193 - val_loss: 1.3835 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 9/30
# 21/21 [==============================] - ETA: 0s - loss: 1.3098 - categorical_accuracy: 0.4676
# Epoch 00009: saving model to model_init_2023-09-0206_29_59.011351/model-00009-1.30976-0.46757-1.36574-0.44000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 1.3098 - categorical_accuracy: 0.4676 - val_loss: 1.3657 - val_categorical_accuracy: 0.4400 - lr: 0.0010
# Epoch 10/30
# 21/21 [==============================] - ETA: 0s - loss: 1.2500 - categorical_accuracy: 0.4977
# Epoch 00010: saving model to model_init_2023-09-0206_29_59.011351/model-00010-1.25001-0.49774-1.20802-0.56000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 1.2500 - categorical_accuracy: 0.4977 - val_loss: 1.2080 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 11/30
# 21/21 [==============================] - ETA: 0s - loss: 1.2064 - categorical_accuracy: 0.5339
# Epoch 00011: saving model to model_init_2023-09-0206_29_59.011351/model-00011-1.20638-0.53394-1.33780-0.46000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 1.2064 - categorical_accuracy: 0.5339 - val_loss: 1.3378 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 12/30
# 21/21 [==============================] - ETA: 0s - loss: 1.1584 - categorical_accuracy: 0.5490
# Epoch 00012: saving model to model_init_2023-09-0206_29_59.011351/model-00012-1.15839-0.54902-1.15570-0.59000.h5
# 21/21 [==============================] - 66s 3s/step - loss: 1.1584 - categorical_accuracy: 0.5490 - val_loss: 1.1557 - val_categorical_accuracy: 0.5900 - lr: 0.0010
# Epoch 13/30
# 21/21 [==============================] - ETA: 0s - loss: 1.0662 - categorical_accuracy: 0.6244
# Epoch 00013: saving model to model_init_2023-09-0206_29_59.011351/model-00013-1.06618-0.62443-1.18175-0.55000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 1.0662 - categorical_accuracy: 0.6244 - val_loss: 1.1818 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 14/30
# 21/21 [==============================] - ETA: 0s - loss: 1.0434 - categorical_accuracy: 0.6169
# Epoch 00014: saving model to model_init_2023-09-0206_29_59.011351/model-00014-1.04344-0.61689-1.25155-0.49000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 [==============================] - 69s 3s/step - loss: 1.0434 - categorical_accuracy: 0.6169 - val_loss: 1.2515 - val_categorical_accuracy: 0.4900 - lr: 0.0010
# Epoch 15/30
# 21/21 [==============================] - ETA: 0s - loss: 0.9677 - categorical_accuracy: 0.6667
# Epoch 00015: saving model to model_init_2023-09-0206_29_59.011351/model-00015-0.96768-0.66667-1.06567-0.62000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.9677 - categorical_accuracy: 0.6667 - val_loss: 1.0657 - val_categorical_accuracy: 0.6200 - lr: 5.0000e-04
# Epoch 16/30
# 21/21 [==============================] - ETA: 0s - loss: 0.9191 - categorical_accuracy: 0.7029
# Epoch 00016: saving model to model_init_2023-09-0206_29_59.011351/model-00016-0.91915-0.70287-1.07141-0.61000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 0.9191 - categorical_accuracy: 0.7029 - val_loss: 1.0714 - val_categorical_accuracy: 0.6100 - lr: 5.0000e-04
# Epoch 17/30
# 21/21 [==============================] - ETA: 0s - loss: 0.8516 - categorical_accuracy: 0.7406
# Epoch 00017: saving model to model_init_2023-09-0206_29_59.011351/model-00017-0.85156-0.74057-1.04603-0.62000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 0.8516 - categorical_accuracy: 0.7406 - val_loss: 1.0460 - val_categorical_accuracy: 0.6200 - lr: 5.0000e-04
# Epoch 18/30
# 21/21 [==============================] - ETA: 0s - loss: 0.8748 - categorical_accuracy: 0.6848
# Epoch 00018: saving model to model_init_2023-09-0206_29_59.011351/model-00018-0.87481-0.68477-1.06726-0.60000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.8748 - categorical_accuracy: 0.6848 - val_loss: 1.0673 - val_categorical_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 19/30
# 21/21 [==============================] - ETA: 0s - loss: 0.8084 - categorical_accuracy: 0.7119
# Epoch 00019: saving model to model_init_2023-09-0206_29_59.011351/model-00019-0.80839-0.71192-1.18974-0.61000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 [==============================] - 68s 3s/step - loss: 0.8084 - categorical_accuracy: 0.7119 - val_loss: 1.1897 - val_categorical_accuracy: 0.6100 - lr: 5.0000e-04
# Epoch 20/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7907 - categorical_accuracy: 0.7330
# Epoch 00020: saving model to model_init_2023-09-0206_29_59.011351/model-00020-0.79072-0.73303-1.01879-0.65000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 0.7907 - categorical_accuracy: 0.7330 - val_loss: 1.0188 - val_categorical_accuracy: 0.6500 - lr: 2.5000e-04
# Epoch 21/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7651 - categorical_accuracy: 0.7572
# Epoch 00021: saving model to model_init_2023-09-0206_29_59.011351/model-00021-0.76506-0.75716-1.02183-0.65000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.7651 - categorical_accuracy: 0.7572 - val_loss: 1.0218 - val_categorical_accuracy: 0.6500 - lr: 2.5000e-04
# Epoch 22/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7547 - categorical_accuracy: 0.7617
# Epoch 00022: saving model to model_init_2023-09-0206_29_59.011351/model-00022-0.75467-0.76169-1.10967-0.58000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 21/21 [==============================] - 68s 3s/step - loss: 0.7547 - categorical_accuracy: 0.7617 - val_loss: 1.1097 - val_categorical_accuracy: 0.5800 - lr: 2.5000e-04
# Epoch 23/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7291 - categorical_accuracy: 0.7692
# Epoch 00023: saving model to model_init_2023-09-0206_29_59.011351/model-00023-0.72911-0.76923-1.03355-0.66000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.7291 - categorical_accuracy: 0.7692 - val_loss: 1.0335 - val_categorical_accuracy: 0.6600 - lr: 1.2500e-04
# Epoch 24/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7132 - categorical_accuracy: 0.7662
# Epoch 00024: saving model to model_init_2023-09-0206_29_59.011351/model-00024-0.71318-0.76621-1.02361-0.64000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 21/21 [==============================] - 66s 3s/step - loss: 0.7132 - categorical_accuracy: 0.7662 - val_loss: 1.0236 - val_categorical_accuracy: 0.6400 - lr: 1.2500e-04
# Epoch 25/30
# 21/21 [==============================] - ETA: 0s - loss: 0.6979 - categorical_accuracy: 0.7798
# Epoch 00025: saving model to model_init_2023-09-0206_29_59.011351/model-00025-0.69788-0.77979-1.02670-0.67000.h5
# 21/21 [==============================] - 67s 3s/step - loss: 0.6979 - categorical_accuracy: 0.7798 - val_loss: 1.0267 - val_categorical_accuracy: 0.6700 - lr: 6.2500e-05
# Epoch 26/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7115 - categorical_accuracy: 0.7541
# Epoch 00026: saving model to model_init_2023-09-0206_29_59.011351/model-00026-0.71146-0.75415-1.00987-0.70000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.7115 - categorical_accuracy: 0.7541 - val_loss: 1.0099 - val_categorical_accuracy: 0.7000 - lr: 6.2500e-05
# Epoch 27/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7140 - categorical_accuracy: 0.7662
# Epoch 00027: saving model to model_init_2023-09-0206_29_59.011351/model-00027-0.71400-0.76621-0.95743-0.64000.h5
# 21/21 [==============================] - 68s 3s/step - loss: 0.7140 - categorical_accuracy: 0.7662 - val_loss: 0.9574 - val_categorical_accuracy: 0.6400 - lr: 6.2500e-05
# Epoch 28/30
# 21/21 [==============================] - ETA: 0s - loss: 0.7151 - categorical_accuracy: 0.7632
# Epoch 00028: saving model to model_init_2023-09-0206_29_59.011351/model-00028-0.71514-0.76320-1.01846-0.67000.h5
# 21/21 [==============================] - 65s 3s/step - loss: 0.7151 - categorical_accuracy: 0.7632 - val_loss: 1.0185 - val_categorical_accuracy: 0.6700 - lr: 6.2500e-05
# Epoch 29/30
# 21/21 [==============================] - ETA: 0s - loss: 0.6692 - categorical_accuracy: 0.7888
# Epoch 00029: saving model to model_init_2023-09-0206_29_59.011351/model-00029-0.66918-0.78884-1.03011-0.64000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 21/21 [==============================] - 68s 3s/step - loss: 0.6692 - categorical_accuracy: 0.7888 - val_loss: 1.0301 - val_categorical_accuracy: 0.6400 - lr: 6.2500e-05
# Epoch 30/30
# 21/21 [==============================] - ETA: 0s - loss: 0.6674 - categorical_accuracy: 0.7903
# Epoch 00030: saving model to model_init_2023-09-0206_29_59.011351/model-00030-0.66742-0.79035-1.03565-0.62000.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.6674 - categorical_accuracy: 0.7903 - val_loss: 1.0356 - val_categorical_accuracy: 0.6200 - lr: 3.1250e-05

# %% [markdown]
# ## We tried with 3 different models:
# ###  - Conv3d with Training Accuracy of 83% & Validation Accuracy of 81%
# ###  - VGGNet16 + RNN with Training Accuracy of 92% & Validation Accuracy of 73%
# ###  - CNN + RNN (GRU) with Training Accuracy of 79% &  Validation Accuracy of 62%
# ### Hence, we'll go with VGG16+RNN(GRU) model as they have lowest cost function for both training/validation (loss: 0.2937/val_loss: 0.5892)
